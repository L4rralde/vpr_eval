# %%
from eval import model_eval
from vpr import models

val_datasets = ['pitts30k_test', 'Nordland', 'SPED']

# %% [markdown]
# ## DINOv3 Imagenet mean-std. **The best**

# %%
dinov3 = models.DinoV3.ViTBase()

# %%
model_eval(
    dinov3,
    img_size = 368,
    mean_std = 'imagenet',
    crop = False,
    val_datasets = val_datasets,
    verbose = False
)
# Out:
# ----------------------------------------------------------------------------------------------------
# 368
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 526/526 [04:26<00:00,  1.97it/s]
# /home/emmanuel/miniconda3/envs/salad_3/lib/python3.10/site-packages/faiss/contrib/torch_utils.py:51: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   x.storage().data_ptr() + x.storage_offset() * 4)
# +----------------------------------------------------------+
# |              Performances on pitts30k_test               |
# +----------+-------+-------+-------+-------+-------+-------+
# |    K     |   1   |   5   |   10  |   15  |   20  |   25  |
# ...

# %% [markdown]
# ## DINOv3 dinov3 mean-std

# %%
model_eval(
    dinov3,
    img_size = 368,
    mean_std = 'dinov3',
    crop = False,
    val_datasets = val_datasets,
    verbose = False
)
# Out:
# ----------------------------------------------------------------------------------------------------
# 368
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 526/526 [02:57<00:00,  2.97it/s]
# +----------------------------------------------------------+
# |              Performances on pitts30k_test               |
# +----------+-------+-------+-------+-------+-------+-------+
# |    K     |   1   |   5   |   10  |   15  |   20  |   25  |
# +----------+-------+-------+-------+-------+-------+-------+
# | Recall@K | 82.82 | 93.91 | 96.39 | 97.26 | 97.89 | 98.40 |
# +----------+-------+-------+-------+-------+-------+-------+
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 949/949 [05:17<00:00,  2.99it/s]
# +----------------------------------------------------------+
# ...

# %% [markdown]
# ## DINOv3 with center crop and imagenet mean-std

# %%
model_eval(
    dinov3,
    img_size = 368,
    mean_std = 'imagenet',
    crop = True,
    val_datasets = val_datasets,
    verbose = False
)
# Out:
# ----------------------------------------------------------------------------------------------------
# 368
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 526/526 [02:26<00:00,  3.60it/s]
# +----------------------------------------------------------+
# |              Performances on pitts30k_test               |
# +----------+-------+-------+-------+-------+-------+-------+
# |    K     |   1   |   5   |   10  |   15  |   20  |   25  |
# +----------+-------+-------+-------+-------+-------+-------+
# | Recall@K | 80.02 | 92.05 | 94.76 | 96.26 | 96.99 | 97.46 |
# +----------+-------+-------+-------+-------+-------+-------+
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 949/949 [03:43<00:00,  4.25it/s]
# +---------------------------------------------------------+
# ...

# %% [markdown]
# ## DINOv3 with center crop and dinov3 mean-std

# %%
model_eval(
    dinov3,
    img_size = 368,
    mean_std = 'dinov3',
    crop = True,
    val_datasets = val_datasets,
    verbose = False
)
# Out:
# ----------------------------------------------------------------------------------------------------
# 368
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 526/526 [02:26<00:00,  3.58it/s]
# +----------------------------------------------------------+
# |              Performances on pitts30k_test               |
# +----------+-------+-------+-------+-------+-------+-------+
# |    K     |   1   |   5   |   10  |   15  |   20  |   25  |
# +----------+-------+-------+-------+-------+-------+-------+
# | Recall@K | 80.37 | 93.19 | 95.85 | 96.89 | 97.43 | 97.83 |
# +----------+-------+-------+-------+-------+-------+-------+
# Calculating descritptors...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 949/949 [04:29<00:00,  3.52it/s]
# +---------------------------------------------------------+
# ...
